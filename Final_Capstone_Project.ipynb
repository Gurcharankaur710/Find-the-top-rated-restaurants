# %% [markdown]
# ### **Find The Top-Rated Restaurant using Classification Techniques**

# %% [markdown]
# ### **Importing libraries**

# %%
import numpy as np               # Numpy is working with multidimensional array object, matrices, scientific computing
import pandas as pd              # Pandas is used for data manipulation and analysis

# %% [markdown]
# ### **Importing Dataset**

# %%
Data = pd.read_csv('zomato.csv')  # Here, we are giving the path of the dataset.'Data' is our Dataframe name.

# %% [markdown]
# ### **Checking the shape of Dataset (Number of record & attributes in data frame)**

# %%
Data.shape                        # We are checking the shape of dataset that how many number of records and attributes we have.
# Out:
# (51717, 17)

# %% [markdown]
# ### **Printing the first five top rows**

# %%
Data.head()       # The head() function is used to get the first n rows in the dataset, by default it select first 5 records from the dataset.
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %% [markdown]
# ### **Printing the last five rows**

# %%
Data.tail()                   # The tail() function is used to get the last n rows in the dataset, by default it select last 5 records from the dataset.
# Out:
#                                                      url  \
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# ...

# %%
Data.head().to_csv("head_Data.csv")              # We are saving the data into csv format

# %% [markdown]
# ### **Checking the Column names**

# %%
Data.columns               # Use of 'Data.columns' to return the column labels or column names of the our dataset.
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %% [markdown]
# ### **Displaying Dataframe structure**

# %%
Data.info()                   # The info() function is used to print a concise summary of a Dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %% [markdown]
# ### **Checking the datatype of each attribute**

# %%
Data.dtypes            # It return the data types in the DataFrame for each column.
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %% [markdown]
# ### **Converting the each attribute names to uppercase charater**

# %%
Data.columns = map(str.upper, Data.columns)            # Converting all colummn names of dataframe to uppercase.
Data.columns
# Out:
# Index(['URL', 'ADDRESS', 'NAME', 'ONLINE_ORDER', 'BOOK_TABLE', 'RATE', 'VOTES',
#        'PHONE', 'LOCATION', 'REST_TYPE', 'DISH_LIKED', 'CUISINES',
#        'APPROX_COST(FOR TWO PEOPLE)', 'REVIEWS_LIST', 'MENU_ITEM',
#        'LISTED_IN(TYPE)', 'LISTED_IN(CITY)'],
#       dtype='object')

# %% [markdown]
# ### **Renaming Attributes**

# %%
Data.rename(columns={'REST_TYPE':'RESTAURANT_TYPE'}, inplace=True)              # Here, we are renaming some attributes for better visualization
Data.rename(columns={'APPROX_COST(FOR TWO PEOPLE)':'COST'}, inplace=True)
Data.rename(columns={'LISTED_IN(TYPE)':'SERVICE_TYPE'}, inplace=True)
Data.rename(columns={'LISTED_IN(CITY)':'CITY'}, inplace=True)
Data.rename(columns={'REVIEWS_LIST':'REVIEWS'}, inplace=True)
Data.columns
# Out:
# Index(['URL', 'ADDRESS', 'NAME', 'ONLINE_ORDER', 'BOOK_TABLE', 'RATE', 'VOTES',
#        'PHONE', 'LOCATION', 'RESTAURANT_TYPE', 'DISH_LIKED', 'CUISINES',
#        'COST', 'REVIEWS', 'MENU_ITEM', 'SERVICE_TYPE', 'CITY'],
#       dtype='object')

# %% [markdown]
# ### **Assigning the appropriate datatype to the column**

# %%
Data['ONLINE_ORDER'] = Data['ONLINE_ORDER'].astype('category')      # Here, we are assigning the correct datatype to the columns in the dataset.
Data['BOOK_TABLE'] = Data['BOOK_TABLE'].astype('category')         
Data['LOCATION'] = Data['LOCATION'].astype('category')
Data['RESTAURANT_TYPE'] = Data['RESTAURANT_TYPE'].astype('category')
Data['SERVICE_TYPE'] = Data['SERVICE_TYPE'].astype('category')
Data['CITY'] = Data['CITY'].astype('category')
Data['CUISINES'] = Data['CUISINES'].astype('category')

# %% [markdown]
# ### **Dropping irrelevant columns**

# %%
#dropping irrelevant columns
Data=Data.drop(['URL','ADDRESS','PHONE','DISH_LIKED','MENU_ITEM'],axis=1)   # Now we have 12 attributes out of 17 attributes, we do not need these attributes thats why we delete it from dataset.
Data.head(2)
# Out:
#              NAME ONLINE_ORDER BOOK_TABLE   RATE  VOTES      LOCATION  \
# 0           Jalsa          Yes        Yes  4.1/5    775  Banashankari
# 1  Spice Elephant          Yes         No  4.1/5    787  Banashankari
#
#   RESTAURANT_TYPE                        CUISINES COST  \
# 0   Casual Dining  North Indian, Mughlai, Chinese  800
# 1   Casual Dining     Chinese, North Indian, Thai  800
#
#                                              REVIEWS SERVICE_TYPE  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...       Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...       Buffet
#
#            CITY
# 0  Banashankari
# 1  Banashankari

# %% [markdown]
# The above attributes- URL, ADDRESS, PHONE, DISH_LIKED, MENU_ITEM are dropped. Because that attributes are not containing any relevant information. Moreover, we are not going to use these attributes further.

# %%
#Rechecking the datatypes
Data.dtypes            # Now, we have 1 integer, 7 category and 4 objects
# Out:
# NAME                 object
# ONLINE_ORDER       category
# BOOK_TABLE         category
# RATE                 object
# VOTES                 int64
# LOCATION           category
# RESTAURANT_TYPE    category
# CUISINES           category
# COST                 object
# REVIEWS              object
# SERVICE_TYPE       category
# CITY               category
# dtype: object

# %% [markdown]
# ### **Displays summary of statistics**

# %%
Data.describe().T              # Describe() generates the descriptive statistics, in our dataset we have votes column for statistics.
# Out:
#          count        mean         std  min  25%   50%    75%      max
# VOTES  51717.0  283.697527  803.838853  0.0  7.0  41.0  198.0  16832.0

# %%
round(Data.describe().T,0)           # Here, we use round parameter for a DataFrame with the affected columns rounded to the specified number of decimal places.
# Out:
#          count   mean    std  min  25%   50%    75%      max
# VOTES  51717.0  284.0  804.0  0.0  7.0  41.0  198.0  16832.0

# %% [markdown]
# ### **Data Cleaning**

# %% [markdown]
# ### **Checking & Removing the duplicate records from the dataset**

# %%
# Checking and Removing the Duplicates
Data.duplicated().sum()
Data.drop_duplicates(inplace=True)

# %% [markdown]
# ### **How many null values in the dataset**

# %%
Data.isnull()             # The function dataframe.isnull() it returns True when there is at least one missing value occurring in the dataset.
# Out:
#         NAME  ONLINE_ORDER  BOOK_TABLE   RATE  VOTES  LOCATION  \
# 0      False         False       False  False  False     False
# 1      False         False       False  False  False     False
# 2      False         False       False  False  False     False
# 3      False         False       False  False  False     False
# 4      False         False       False  False  False     False
# ...      ...           ...         ...    ...    ...       ...
# 51712  False         False       False  False  False     False
# 51713  False         False       False   True  False     False
# 51714  False         False       False   True  False     False
# 51715  False         False       False  False  False     False
# 51716  False         False       False  False  False     False
#
#        RESTAURANT_TYPE  CUISINES   COST  REVIEWS  SERVICE_TYPE   CITY
# 0                False     False  False    False         False  False
# ...

# %%
Data.isnull().sum()                    
Data.isnull().sum().to_csv("Missing_Values.csv")                 # We are saving the mising data into csv format

# %%
Data.isnull().sum().sort_values(ascending=False)            # The function dataframe.isnull().sum() returns the number of missing values in the data set. 
                                                            # So, we can have the sum of all attributes with null values thats why we use sum() for better visualization.
                                                            # Here we are sorting the values with asending false, It gives the value in return as descending order.
#Numeric_data.to_excel("Missing_Value.xls")
# Out:
# RATE               7757
# COST                345
# RESTAURANT_TYPE     227
# CUISINES             45
# LOCATION             21
# NAME                  0
# ONLINE_ORDER          0
# BOOK_TABLE            0
# VOTES                 0
# REVIEWS               0
# SERVICE_TYPE          0
# CITY                  0
# dtype: int64

# %% [markdown]
# ### **Replacing the missing vales from the dataset by column wise**

# %%
Data.RATE    # here, we cam see that we have white spaces, null vales in the rate column. so, we replace it with the help of 'new' and '-' as it is a object attribute.
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51712    3.6 /5
# 51713       NaN
# 51714       NaN
# 51715    4.3 /5
# 51716    3.4 /5
# Name: RATE, Length: 51645, dtype: object

# %%
Data['RATE'] = Data['RATE'].str.replace(' ', '')              # let us first remove the whitespace.
                                                              # re assign back this to the same rate column

# %%
Data['RATE'].replace('NEW', np.nan, inplace=True)               # lets take care of NEW AND - with nan means marking as missing and then we will take care of that.
Data['RATE'].replace('-', np.nan, inplace=True)                 # here we are using np.nan from numpy module, inplace=True makes the permanent impact.

# %%
#Removing the "/5" from Rate attribute
Data['RATE'] = Data['RATE'].str.replace("/5", "").astype('float')               # making rate column with only rating instead of "/5" using string replace() method
Data['RATE'].head(3)                                                            # changing the data type to float using astype() because rate column us always in numeric
                                                                                # reassign back to that column
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# Name: RATE, dtype: float64

# %%
Data['RATE'] = Data['RATE'].fillna(Data['RATE'].mean())       # Replacing the NaN values in rate feature. Before that it was object thats and now it a numeric attribute.

# %%
Data.COST
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51712    1,500
# 51713      600
# 51714    2,000
# 51715    2,500
# 51716    1,500
# Name: COST, Length: 51645, dtype: object

# %%
# Converting the cost variaible into numeric
Data['COST'] = Data['COST'].astype(str)                           # To convert the varible to a float we could simply do astype(float)
Data['COST'] = Data['COST'].apply(lambda x: x.replace(',',''))    # This method wont work because of presence of comma in between the numbers eg. 1,000
Data['COST'] = Data['COST'].astype(float)       # To avoid this kind of problem, we are using lambda and replace function to replace comma with nothing and then convert to float
Data['COST']
# Out:
# 0         800.0
# 1         800.0
# 2         800.0
# 3         300.0
# 4         600.0
#           ...
# 51712    1500.0
# 51713     600.0
# 51714    2000.0
# 51715    2500.0
# 51716    1500.0
# Name: COST, Length: 51645, dtype: float64

# %%
Data['COST'] = Data['COST'].fillna(Data['COST'].mean())         # Replacing the NaN values for the cost with mean value

# %%
Data['VOTES'] = Data['VOTES'].fillna(0)                     # Here, we fill null values with zero

# %%
#May have contrasting inputs but best for data to be filled with mode.
Data["LOCATION"] = Data['LOCATION'].fillna(Data["LOCATION"].mode().iloc[0])
Data["RESTAURANT_TYPE"] = Data["RESTAURANT_TYPE"].fillna(Data["RESTAURANT_TYPE"].mode().iloc[0])
Data["CUISINES"] = Data["CUISINES"].fillna(Data["CUISINES"].mode().iloc[0])

# %%
#Rechecking the dataset after replacing missing value
pd.DataFrame(Data.isnull().sum(), columns= ['Number of missing values'])
# Out:
#                  Number of missing values
# NAME                                    0
# ONLINE_ORDER                            0
# BOOK_TABLE                              0
# RATE                                    0
# VOTES                                   0
# LOCATION                                0
# RESTAURANT_TYPE                         0
# CUISINES                                0
# COST                                    0
# REVIEWS                                 0
# SERVICE_TYPE                            0
# CITY                                    0

# %% [markdown]
# ### **Counting the total unique values for categorical attributes**

# %%
# Unique values for all Categorical attributes (Online order, Book table, Location, Restaurant type, Service type, City, Cuisines)
#Online Order
y = (Data['ONLINE_ORDER']).value_counts()        # Here, we have two methods to count of all unique values for the column online order.
print(y)
# Out:
# Yes    30386
# No     21259
# Name: ONLINE_ORDER, dtype: int64

# %%
Data['ONLINE_ORDER'].value_counts()             # This is the second method to count the values for the columns.
# Out:
# Yes    30386
# No     21259
# Name: ONLINE_ORDER, dtype: int64

# %%
Data["ONLINE_ORDER"].unique()                 # Unique() can returns when the input is an index, categorical dtype. So, we have categorical datatype in our dataset.
                                              # we are just checking unique values for categorical datatype.
# Out:
# ['Yes', 'No']
# Categories (2, object): ['No', 'Yes']

# %%
#Book table
Data['BOOK_TABLE'].value_counts()        # Here, we are counting of all values for the column book table.
# Out:
# No     45208
# Yes     6437
# Name: BOOK_TABLE, dtype: int64

# %%
Data["BOOK_TABLE"].unique()                    # Book table is also categorical, so we are checking the levels here.
# Out:
# ['Yes', 'No']
# Categories (2, object): ['No', 'Yes']

# %%
#Location
Data['LOCATION'].value_counts()              # Here, we are counting of all values for the location.
# Out:
# BTM                      5130
# HSR                      2522
# Koramangala 5th Block    2503
# JP Nagar                 2234
# Whitefield               2141
#                          ...
# West Bangalore              6
# Yelahanka                   6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: LOCATION, Length: 93, dtype: int64

# %%
Data["LOCATION"].unique()                         # loaction table is also categorical, so we are checking the levels here.
# Out:
# ['Banashankari', 'Basavanagudi', 'Mysore Road', 'Jayanagar', 'Kumaraswamy Layout', ..., 'West Bangalore', 'Magadi Road', 'Yelahanka', 'Sahakara Nagar', 'Peenya']
# Length: 93
# Categories (93, object): ['BTM', 'Banashankari', 'Banaswadi', 'Bannerghatta Road', ...,
#                           'Whitefield', 'Wilson Garden', 'Yelahanka', 'Yeshwantpur']

# %%
#Restaurant Type
Data['RESTAURANT_TYPE'].value_counts()              # Here, we are counting of all values for the restaurant.
# Out:
# Quick Bites                   19328
# Casual Dining                 10316
# Cafe                           3730
# Delivery                       2600
# Dessert Parlor                 2261
#                               ...
# Cafe, Food Court                  2
# Pop Up                            2
# Bakery, Food Court                2
# Quick Bites, Kiosk                1
# Sweet Shop, Dessert Parlor        1
# Name: RESTAURANT_TYPE, Length: 93, dtype: int64

# %%
Data["RESTAURANT_TYPE"].unique()                      # Rest_type table is also categorical, so we are checking the levels here.
# Out:
# ['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites', 'Casual Dining, Cafe', 'Cafe', ..., 'Quick Bites, Kiosk', 'Lounge, Microbrewery', 'Food Court, Beverage Shop', 'Dessert Parlor, Food Court', 'Bar, Lounge']
# Length: 93
# Categories (93, object): ['Bakery', 'Bakery, Beverage Shop', 'Bakery, Cafe',
#                           'Bakery, Dessert Parlor', ..., 'Sweet Shop, Dessert Parlor',
#                           'Sweet Shop, Quick Bites', 'Takeaway', 'Takeaway, Delivery']

# %%
#Service type
Data['SERVICE_TYPE'].value_counts()                 # Here, we are counting of all values for the column listed_in type.
# Out:
# Delivery              25888
# Dine-out              17763
# Desserts               3593
# Cafes                  1723
# Drinks & nightlife     1101
# Buffet                  881
# Pubs and bars           696
# Name: SERVICE_TYPE, dtype: int64

# %%
Data["SERVICE_TYPE"].unique()                          # listed_in type is also categorical, so we are checking the levels here.
# Out:
# ['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out', 'Drinks & nightlife', 'Pubs and bars']
# Categories (7, object): ['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out',
#                          'Drinks & nightlife', 'Pubs and bars']

# %%
#City
Data['CITY'].value_counts()                    # Here, we are counting of all values for the column listed_in city.
# Out:
# BTM                      3268
# Koramangala 7th Block    2935
# Koramangala 5th Block    2834
# Koramangala 4th Block    2777
# Koramangala 6th Block    2622
# Jayanagar                2366
# JP Nagar                 2095
# Indiranagar              1858
# Church Street            1809
# MG Road                  1807
# Brigade Road             1769
# Lavelle Road             1741
# HSR                      1741
# Marathahalli             1658
# Residency Road           1620
# Whitefield               1618
# Bannerghatta Road        1616
# Brookefield              1517
# Old Airport Road         1424
# Kammanahalli             1326
# Kalyan Nagar             1306
# Basavanagudi             1266
# Sarjapur Road            1259
# Electronic City          1227
# Bellandur                1226
# Frazer Town              1185
# Malleshwaram             1095
# Rajajinagar              1078
# Banashankari              862
# New BEL Road              740
# Name: CITY, dtype: int64

# %%
Data["CITY"].unique()               # City is also categorical, so we are checking the levels here.
# Out:
# ['Banashankari', 'Bannerghatta Road', 'Basavanagudi', 'Bellandur', 'Brigade Road', ..., 'Old Airport Road', 'Rajajinagar', 'Residency Road', 'Sarjapur Road', 'Whitefield']
# Length: 30
# Categories (30, object): ['BTM', 'Banashankari', 'Bannerghatta Road', 'Basavanagudi', ...,
#                           'Rajajinagar', 'Residency Road', 'Sarjapur Road', 'Whitefield']

# %%
#Cuisines
Data['CUISINES'].value_counts()                    # Here, we are counting of all values for the column listed_in city.
# Out:
# North Indian                                   2952
# North Indian, Chinese                          2381
# South Indian                                   1826
# Biryani                                         915
# Bakery, Desserts                                910
#                                                ...
# South Indian, Biryani, Chettinad, Juices          1
# Hyderabadi, Andhra, Chinese, Biryani              1
# Healthy Food, Salad, Mediterranean                1
# North Indian, Continental, Chinese, Seafood       1
# Mithai, Gujarati                                  1
# Name: CUISINES, Length: 2723, dtype: int64

# %%
Data["CUISINES"].unique()               # Cuisines is also categorical, so we are checking the levels here.
# Out:
# ['North Indian, Mughlai, Chinese', 'Chinese, North Indian, Thai', 'Cafe, Mexican, Italian', 'South Indian, North Indian', 'North Indian, Rajasthani', ..., 'Italian, North Indian, Continental, BBQ', 'Tibetan, Nepalese', 'North Indian, Street Food, Biryani', 'Chinese, Mughlai', 'North Indian, Chinese, Arabian, Momos']
# Length: 2723
# Categories (2723, object): ['African, Burger', 'African, Burger, Desserts, Beverages, Fast Food',
#                             'American', 'American, Asian, Continental, North Indian, S...,
#                             ..., 'Turkish, Rolls', 'Vietnamese', 'Vietnamese, Salad',
#                             'Vietnamese, Thai, Burmese, Japanese']

# %% [markdown]
# ### **Replacing the Yes/No with numbers**

# %%
Data.ONLINE_ORDER.replace(('Yes','No'),(1, 0),inplace=True)
Data.BOOK_TABLE.replace(('Yes','No'),(1, 0),inplace=True)
Data.head(2).T
# Out:
#                                                                  0  \
# NAME                                                         Jalsa
# ONLINE_ORDER                                                     1
# BOOK_TABLE                                                       1
# RATE                                                           4.1
# VOTES                                                          775
# LOCATION                                              Banashankari
# RESTAURANT_TYPE                                      Casual Dining
# CUISINES                            North Indian, Mughlai, Chinese
# COST                                                         800.0
# REVIEWS          [('Rated 4.0', 'RATED\n  A beautiful place to ...
# SERVICE_TYPE                                                Buffet
# CITY                                                  Banashankari
#
#                                                                  1
# ...

# %%
Data.info()                   # Recheck the data types after dropping irrelevant column and assigning the correct data type.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51645 entries, 0 to 51716
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             51645 non-null  object
#  1   ONLINE_ORDER     51645 non-null  int64
#  2   BOOK_TABLE       51645 non-null  int64
#  3   RATE             51645 non-null  float64
#  4   VOTES            51645 non-null  int64
#  5   LOCATION         51645 non-null  category
#  6   RESTAURANT_TYPE  51645 non-null  category
#  7   CUISINES         51645 non-null  category
#  8   COST             51645 non-null  float64
#  9   REVIEWS          51645 non-null  object
#  10  SERVICE_TYPE     51645 non-null  category
#  11  CITY             51645 non-null  category
# dtypes: category(5), float64(2), int64(3), object(2)
# memory usage: 3.5+ MB

# %% [markdown]
# Now, we have toatl 5 category, 2 float, 1 int, 2 object and 2 uint. # uint8 is an 8 bit unsigned integer which can store only positive value.

# %% [markdown]
# ### **Descriptive Analytics after assiging correct Datatype to Attributes**

# %%
#Descriptive Analytics of quantitative variables in the dataframe
round(Data.describe().T,0)           # Here, we use round parameter for a DataFrame with the affected columns rounded to the specified number of decimal places.
                                     # Before that we had just 1 numeric attribute and now we have 5 numeric attributes
round(Data.describe().T,0).to_csv("Descriptive_table.csv")      # We are saving the descriptive data into csv format

# %% [markdown]
# ### **Exploratory data analysis**

# %%
# Importing necessary Libraries
import matplotlib.pyplot as plt          # It is used for creating various plots
import seaborn as sns                    # Seaborn is used for data visualization and exploratory data analysis

# %% [markdown]
# ### **How many restaurants have online order options?**

# %%
Data["ONLINE_ORDER"].value_counts().plot(kind = 'pie',                    # Show value counts for a single categorical variable. Here, we select pie chart to plot.
                                         autopct = '%.2f',                # To having the each wedge on the top we use autopct Show data in percentage for with 2 decimal point, 
                                              radius = 1,                 # Radius to increase or decrease the size of pie chart,
                                        colors = ['Thistle', 'DarkSlateBlue'], explode = [0,0.1],       # here, we set the color for each section and set explode to slice the perticuler section
                                        labels = ['Yes', 'No'], shadow=True, startangle = 40,               # set the labels and shadow is on for better look
                                        textprops = dict(size=12), wedgeprops = {'edgecolor' : 'black'})     # textprops is used for font size of text in chart, wedgeprops for linewidth of pie chart
plt.axis('off')                              # we off the axis for better visualization its just showing attribute name(book_table)
plt.title('Percentage of restaurants that allow online ordering')       # set the title
plt.savefig('Percentage of Online ordering.jpg')              # we are saving the figure as jpg.
plt.show()                                                    # To show the pie chart

# %% [markdown]
# **Explanation:** This pie chart gives the information about the restaurants doing online order or not. More than half (58.84%) of the restaurants in the Bangalore city are providing option for online order. However, 41.16% restaurants are not having option of online order.

# %% [markdown]
# ### **How many restaurants have table booking option?**

# %%
Data["BOOK_TABLE"].value_counts().plot(kind = 'pie',                          # Show value counts for a single categorical variable. Here, we select pie chart to plot.
                                       autopct = '%.2f',          # autopct is used to show data in percentage for with 2 decimal point, 
                                       radius = 1,                #Radius to increase or decrease the size of pie chart
                                        colors = ['LightSteelBlue', 'SlateGray'], explode = [0,0.35],    # here, we set the colors 
                                        labels = ['Yes','No'], shadow = True, startangle = -335,              # set the labels and shadow is on for better look
                                      textprops = dict(size=8), wedgeprops = {'edgecolor' : 'black'})  # textprops is used for font size of text in chart, wedgeprops for linewidth of pie chart
plt.axis('off')                                             # we off the axis for better visualization its just showing attribute name(book_table)
plt.title('Percentage of restaurants that allow table booking')   # set the title
plt.savefig('Percentage of Table booking.jpg')              # we are saving the figure as jpg.
plt.show()                                                  # To show pie chart only

# %% [markdown]
# **Explanation:** It shows how much restaurants are allowing to pre booking of the table or not. More than half (87.54%) of the restaurants providing table booking option and only 12.46% of the restaurants are not having table-booking option.

# %% [markdown]
# ### **How many types of service are present in the restaurants?**

# %%
#How many types of service are present in the restaurants
sns.set_style("darkgrid")                     # Set the theme style as darkgrid.
plt.figure(figsize = (15,5))                  # Set the figure size
ax = sns.countplot(x = 'SERVICE_TYPE', data = Data)       # Select the "Service" column for countplot
plt.title('How many types of service in the restaurants', fontsize=18, fontweight='bold')   # Set the title of the graph
total = float(len(Data))                      # set the total data in the float type
plt.xlabel("Service Type")                    # set the x lables for the chart
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')     # here we use for loop for labels to each bar 
for p in ax.patches:                                        # here we use for loop for labels to each bar
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)     # we used for loop to loop over each bar and add text over it using text() function.
    x = p.get_x() + p.get_width()                                 # We used label variable to store the names of variables.
    y = p.get_height()                                            # first we used the get_height function to get height then
    ax.annotate(percentage, (x, y),ha='center')                   # Annotate the point xy with text text
plt.savefig('Types of services.jpg')                 # we are saving the figure as jpg format.
plt.show()                                          # Showing the plot

# %% [markdown]
# **Explanation:** There are total 7 type of services in the restaurants. Top-notch service is the delivery option. From these services, customers like to Dine-out and do delivery type of service, as compared to the other types like buffet, cafes and bars etcetra.

# %% [markdown]
# ### **Top 5 restaurants name in Bengaluru**

# %%
#Top 5 restaurants in Bengaluru
Data["NAME"].value_counts()[:5].plot(                     # Select the "Name" column and it Counts the values in the "Name" attributes,
                                                          # it select the first 5 most-frequently occurring name from the last Series, created by .value_counts().
                                     kind='pie',          # We are creating a pie chart which has the value of each wedge written on the top off the wedge. 
                                     autopct='%1.1f%%',   # To having the each wedge on the top we use autopct.  
                                     startangle= -90,     # We use startangle to give the postion to the pie chart, default startangle is 0.
                                     figsize=(16,5),      # Here we set the figure size
                                     shadow= True,       # we do not need shadow around the wedges.
                                     labels=None,         # Here we donot need labels on the top of wedge.
                                     pctdistance=1.12,    # We are positioning the texts manually using a predefined list of pctdistances.
                                    wedgeprops ={'edgecolor' : 'black'})
plt.title('Top 5 Restaurants in Bangaluru')               # set the title 
sns.set_theme(style="darkgrid")                           # Set the theme style as darkgrid.
plt.axis('equal')                                         # Equal aspect ratio ensures that pie is drawn as a circle.
plt.legend(labels=Data["NAME"].value_counts().index, loc='center left')         # Here, we set the labels and 
plt.tight_layout()                                        # It is used for default padding
plt.savefig('Top 5 Restaurant names.jpg')                 # we are saving the figure as jpg format.
plt.show()         # Showing the plot

# %% [markdown]
# **Explanation:** This pie chart gives the information about the top five restaurants in Bangalore. Top first restaurant is Café Coffee Day (24.3%); second one Onesta (21.5%), third one is Just Bake (18.5%).

# %% [markdown]
# ### **What kind of cuisine is most popular in the locality?**

# %%
# Lets take the top 10 Cusines having restaurants and plot bar graph
histo = Data.groupby('CUISINES')['RESTAURANT_TYPE'].count().sort_values(ascending=False)            # It count of values within each group
histo = histo.sort_values()[-10:]                          # Here, we are fetching the top 20 cuisines from the dataset
axis = histo.plot(kind='bar',                              # we are ploting bar chart
                  figsize=(15, 6),                         # Assigning the figure size
                  rot=90,                                  # Set the angle of the bar plot
                  width = 0.8,                             # set the width of the bar plot
                  color=[ '#581845'])                       # Here, we set the color purple for bars
rects = axis.patches          # Here, we create a rectangle patch
labels = list(histo)                                       # Make some labels
for rect, label in zip(rects, labels):                     # here we use for loop for labels to each bar 
    height = rect.get_height()                             # first we used the get_height function to get height then
    axis.text(rect.get_x() + rect.get_width() / 2,         # we used for loop to loop over each bar and add text over it using text() function.
              height + 1, label,                           #  We used label variable to store the names of variables.
            ha='center', va='bottom', fontsize=10)            # set the font size of chart
axis.xaxis.set_tick_params(labelsize=10)                      # set xticks as 10
axis.legend(fontsize=10)                                      # set legend sie as 10
axis.set_title('Top 10 Cuisines in the Restaurants', fontsize=12)              # set title and add font size as 12
axis.set_xlabel('Cuisines', fontsize=12)               # set the xlabel
axis.grid(False)                          # remove the grid
axis.set_facecolor("Lavender")                # set the background color as pink
axis.legend(['Restaurants'])             # set the legend name as Restaurants
plt.savefig('Top 10 cuisines.jpg')                    # we are saving the figure as jpg.

# %% [markdown]
# **Explanation:** The bar chart shows the top 10 cuisines which are mostly liked by the customer. The very first cuisine, which is popular, is North Indian cuisine. Second one is Chinese. However, among top 10 Bakery is at the end.

# %% [markdown]
# ### **How many numbers of restaurants in each neighborhood?**

# %%
# Checking the number of restaurants in the neighbourhood
histo = Data.groupby('CITY')['RESTAURANT_TYPE'].count().sort_values(ascending=False)[:20]     # It count of values within each group, we are fetching the top 20 cities having number of resturants
axis = histo.plot(kind='bar',                               # we are ploting bar chart
                figsize=(15, 6),                            # Assigning the figure size                         
                rot=90,                                     # Set the angle of the bar plot
                width = 0.8,                                # set the width of the bar plot
                color=[ '#900C3F'])                          # Here, we set the color purple for bars
rects = axis.patches                    # Here, we create a rectangle patch
labels = list(histo)                    # Make some labels
for rect, label in zip(rects, labels):                 # here we use for loop for labels to each bar 
    height = rect.get_height()                              # first we used the get_height function to get height then
    axis.text(rect.get_x() + rect.get_width() / 2,          #  we used for loop to loop over each bar and add text over it using text() function.
            height + .05, label,                            #  We used label variable to store the names of variables.
            ha='center', va='bottom', fontsize=10)          # set the font size of chart 
axis.xaxis.set_tick_params(labelsize=10)                    # set xticks as 10
axis.legend(fontsize=10)                                    # set legend size as 10
axis.set_title('How many restaurants in the cities of bangelore ', fontsize=12)            # set title and add font size as 12
axis.set_xlabel('Cities of Bengaluru', fontsize=12)                # set the xlable size as 12
axis.set_facecolor("Lavender")          # set the background color pink
axis.grid(False)                    # remove the grid
axis.legend(['Restaurants'])       # # set the legend name as Restaurants
plt.savefig('Top 20 cities in bangalore.jpg')                    # we are saving the figure as jpg.

# %% [markdown]
# **Explanation:** This bar chart represents the count of restaurants in each neighbourhood of the Bangalore city. BTM (3268) is having highest number of restaurants. On the contrary, Old airport road and Kammanahalli locations are having lowest number of restaurants.

# %% [markdown]
# ### **Scatter plot of showing the relationship between cost and rating attributes**

# %%
# A scatter plot showing the relationship between cost and rating
plt.figure(figsize=(10,7))                            # Here, we set the figure size
sns.regplot(y=Data.RATE, x=Data.COST)                 # Plot the relationship between two variables in a DataFrame
sns.regplot(x=Data.COST, y=Data.RATE, color="Red")    # set the color for scatter plot
plt.savefig('Relationship of cost and rating.jpg')                    # we are saving the figure as jpg.

# %% [markdown]
# **Explanation:** By analysing the scatter plot, we can say that there is fairly strong correlation between cost and rate, which makes sense because those with higher cost will ensure that both the food and dining experience is good.
# (It can be useful in data analysis and modeling to better understand the relationships between variables. The statistical relationship between two variables is referred to as their correlation).

# %% [markdown]
# ### **Scatter plot of showing the relationship between cost and number of votes attributes**

# %%
# A scatter plot showing the relationship between cost and number of votes
plt.figure(figsize=(10,7))                           # set figure size
sns.regplot(x=Data.VOTES,y=Data.COST)                     # Plot the relationship between two variables in a DataFrame
sns.regplot(x=Data.VOTES, y=Data.COST, color="Purple")    # set the color for scatter plot
plt.savefig('Relationshio of cost and votes.jpg')         # we are saving the figure as jpg.

# %% [markdown]
# **Explanation:** By analysing the scatter plot, we can see that there is a high density of points that are both under cost 1000 and under 2500 votes. A reason for this is that there are more restaurants that over around that price range. There is still a correlation between cost and votes but not quite as strong and we can even see that the variation is higher as seen in the wider blue area around the line. This means that there could be certain outliers present in the data.

# %% [markdown]
# ### **Restaurant rating distibution**

# %%
# Restaurant rating distibution
data = Data['RATE'].dropna()
plt.figure(figsize=(10,6))                       # Set the figure size of histogram
plt.hist(data, color = 'purple', edgecolor = 'black', bins = 20)   # matplotlib histogram
sns.distplot(data, hist=True, kde=False                      # seaborn histogram
             , color = 'purple', bins = 20,  hist_kws={'edgecolor':'black'})      # Here, we set the color of bars and bar edgecolor
plt.title('Highest rating restauarnts')        # Add title
plt.xlabel('Ratings Range')                 # Add labels
plt.savefig('Rating distribution.jpg')                 # we are saving the figure as jpg format.
plt.show()         # Showing the plot
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Explanation:** The bar chart demonstrates the information about the highest rating distribution. In the whole Bangalore city, 17500 restaurants are having highest rating, which is vary between 3.5 to 4.0

# %% [markdown]
# ### **Does cost effects the ratings of the restaurants in cities of Bengaluru**

# %%
# Grouping data by city
grouping = Data.groupby(by='CITY', as_index=False,).agg({'RATE': 'mean','COST': 'mean'})    # here we are taking city attribute to check the aggregate of rate and cost attribute
grouping.sort_values(by='RATE',ascending=False, inplace=True)                        # Here we are sorting the group values of Rate attribute
# Ploting        
fig, ax = plt.subplots(figsize=(18, 10))          # set the size of figure 
sns.barplot(x='CITY', y='COST', data=grouping, palette='coolwarm', order=grouping['CITY'])  # Making the bar chart with cost and rate with city 
ax2 = ax.twinx()                                                       # set the line plot axis
sns.lineplot(x='CITY', y='RATE', data=grouping, color= 'brown')         # set the line plot axis for rating

# Labeling line chart (rate)
xs = np.arange(0, len(grouping), 1)                  # Here we are making line chart for rate 
ys = grouping['RATE']                                # y axis is returing the rate values 
for x,y in zip(xs, ys):                              # using for loop for x and y axis 
    label = "{:.2f}".format(y)                       # set the labels for rating
    plt.annotate(label,        # this is the text
                 (x,y),        # this is the point to label
                 textcoords="offset points",    # how to position the text
                 xytext=(0,16),    # distance from text to points (x,y)
                 ha='center',      # horizontal alignment can be left, right or center
                 color='black')    # Set the color for rating labels
    
# Labeling bar chart (cost)
for p in ax.patches:
    x = p.get_bbox().get_points()[:, 0]
    y = p.get_bbox().get_points()[1, 1]
    ax.annotate('{}'.format(int(y)), (x.mean(), 15), va='bottom', rotation='vertical', color='black', fontweight='bold') # we set the color, rotation of the text and 
ax.tick_params(axis='x', labelrotation=90)                       # Customizing chart and we ser the label rotation and axis of the label
ax.set_title('Does cost effects the ratings of the restaurants in cities of Bengaluru')   # set the title of the chart
plt.savefig('Cost and Rating Comparison.jpg')                   # we are saving the figure as jpg format.
plt.show()                                                     # Showing the plot

# %% [markdown]
# **Explanation:** Above are the top 30 cities in which customers likes to dine in and takeout. In the mentioned cities, the cost of 2 person lies in between 774 to 448 and rating is varied between 3.79 to 3.52. By analysing the above graph, we can say that cost does not affect the rating of the restaurants in Bengaluru.

# %% [markdown]
# ### **Histogram for Votes attribute**

# %%
#Histogram for Votes
sns.distplot(Data['VOTES'])            # making the histogram for votes attribute
plt.title("Votes Histogram")           # Set the title of histogram
plt.savefig('Histogram Votes before Outliers.jpg')      # save the figure into jpg format
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Explanation:** Above is histogram of Votes attribute which shows that most of the data falls into right side which means its right skewed histogram. Variation lies between 0 to 2500.

# %%
sns.boxplot(x = 'VOTES', data = Data)                   # making boxplot for checking the outliers in votes attribute
plt.tight_layout()                                      # set the tight layout of boxplot
plt.show()                                              # showing the boxplot

# %% [markdown]
# **Explanation:** It shows that Votes attribute is having so much outliers. So, we use IQR method to remove the outliers.

# %% [markdown]
# **IQR score:** Basically, Box plot use the IQR method to display data and outliers(shape of the data) but in order to be get a list of identified outlier, we will need to use the mathematical formula and retrieve the outlier data. That's why we use IQR score method to remove the outliers from our dataset.

# %%
# Removing the outliers from votes attribute
Q1 = Data.VOTES.quantile(0.25)
Q3 = Data.VOTES.quantile(0.75)
Q1, Q3
# Out:
# (7.0, 198.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# 191.0

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (-279.5, 484.5)

# %%
index = Data.loc[~(Data.VOTES>upper_limit),"VOTES"].index
index
# Out:
# Int64Index([    3,     4,     5,     6,     8,    10,    11,    12,    13,
#                15,
#             ...
#             51707, 51708, 51709, 51710, 51711, 51712, 51713, 51714, 51715,
#             51716],
#            dtype='int64', length=44689)

# %%
Data = Data.loc[index]
Data
# Out:
#                                                     NAME  ONLINE_ORDER  \
# 3                                  Addhuri Udupi Bhojana             0
# 4                                          Grand Village             0
# 5                                        Timepass Dinner             1
# 6        Rosewood International Hotel - Bar & Restaurant             0
# 8                                         Penthouse Cafe             1
# ...                                                  ...           ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...             0
# 51713                           Vinod Bar And Restaurant             0
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...             0
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...             0
# 51716                       The Nest - The Den Bengaluru             0
#
#        BOOK_TABLE      RATE  VOTES                    LOCATION  \
# ...

# %%
sns.boxplot(x = 'VOTES', data = Data)           # Making boxplot after removing outliers
plt.tight_layout()                              # set the tight layout of boxplot
plt.savefig('Boxplot After Outliers for Votes.jpg')         # save the figure into jpg format
plt.show()                                                  # showing the figure of boxplot

# %% [markdown]
# **Explanation:** This is the Votes boxplot. It looks like this after removing the outliers.

# %% [markdown]
# ### **Histogram for Cost attribute**

# %%
#Histogram for Cost
sns.distplot(Data['COST'])
plt.title("Cost Histogram")
plt.savefig('Cost Histogram before Outlier.jpg')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Explanation:** This is the Cost attribute histogram. It is the right skewed histogram because the data falls into the right side.

# %%
plt.hist(Data.COST, bins=20, rwidth=0.8)    # It is a kind of bar graph. To construct a histogram, the first step is to “bin” the range of values
plt.xlabel('COST')                          # Set the x label
plt.ylabel('Count')                         # set the y label
plt.show()                                  # show the figure

# %% [markdown]
# **Explanation:** It is a kind of bar graph. To construct a histogram, the first step is to “bin” the range of values — that is, divide the entire range of values into a series of intervals — and then count how many values fall into each interval. The bins are usually specified as consecutive, non-overlapping intervals of a variable. This bar chart shows the data varies between 0 to 2000. The maximum count of cost attribute is 17500.

# %%
sns.boxplot(x = 'COST', data = Data)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Explanation:** The boxplot is of Cost attribute which is having outliers. We use IQR method to remove those outliers.

# %%
# Removing the outliers from Cost attribute
Q1 = Data.COST.quantile(0.25)
Q3 = Data.COST.quantile(0.75)
Q1, Q3
# Out:
# (300.0, 600.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# 300.0

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (-150.0, 1050.0)

# %%
index = Data.loc[~(Data.COST>upper_limit),"COST"].index
index
# Out:
# Int64Index([    3,     4,     5,     6,     8,    10,    11,    12,    13,
#                15,
#             ...
#             51643, 51644, 51645, 51674, 51675, 51677, 51709, 51710, 51711,
#             51713],
#            dtype='int64', length=42370)

# %%
Data = Data.loc[index]
Data
# Out:
#                                                   NAME  ONLINE_ORDER  \
# 3                                Addhuri Udupi Bhojana             0
# 4                                        Grand Village             0
# 5                                      Timepass Dinner             1
# 6      Rosewood International Hotel - Bar & Restaurant             0
# 8                                       Penthouse Cafe             1
# ...                                                ...           ...
# 51677                                          Bhagini             0
# 51709                       The Farm House Bar n Grill             0
# 51710                                     Topsy Turvey             0
# 51711                                          Bhagini             0
# 51713                         Vinod Bar And Restaurant             0
#
#        BOOK_TABLE      RATE  VOTES      LOCATION     RESTAURANT_TYPE  \
# ...

# %%
sns.boxplot(x = 'COST', data = Data)
plt.tight_layout()
plt.savefig('Cost boxplot after outlier.jpg')
plt.show()

# %% [markdown]
# **Explanation:** Above boxplot is of Cost attribute. After removing outliers now it is looking like this.

# %% [markdown]
# ### **Histogram for Rate attribute**

# %%
#Histogram for Rate
sns.distplot(Data['RATE'])
plt.title("Rate Histogram")
plt.savefig('Rate histogram before outlier.jpg')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Explanation:** This histogram shows the values of Rate attribute. The value lies between 2.5 to 4.5

# %%
plt.hist(Data.RATE, bins=20, rwidth=0.8)
plt.xlabel('Rate')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Explanation:** The bar chart shows the information about Rate attribute. It demonstrates that the rating vary between 2.5 to 4.5 out of 5.

# %%
sns.boxplot(x = 'RATE', data = Data)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Explanation:** The above boxplot is of attribute Rate. This attribute is having outlier and we are going to remove with IQR method in the following commands.

# %%
# Removing the outliers from Rate attribute
Q1 = Data.RATE.quantile(0.25)
Q3 = Data.RATE.quantile(0.75)
Q1, Q3
# Out:
# (3.4, 3.8)

# %%
IQR = Q3-Q1
IQR
# Out:
# 0.3999999999999999

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (2.8, 4.3999999999999995)

# %%
index = Data.loc[~(Data.RATE>upper_limit),"RATE"].index
index
# Out:
# Int64Index([    3,     4,     5,     6,     8,    10,    11,    12,    13,
#                15,
#             ...
#             51643, 51644, 51645, 51674, 51675, 51677, 51709, 51710, 51711,
#             51713],
#            dtype='int64', length=41927)

# %%
Data = Data.loc[index]
Data
# Out:
#                                                   NAME  ONLINE_ORDER  \
# 3                                Addhuri Udupi Bhojana             0
# 4                                        Grand Village             0
# 5                                      Timepass Dinner             1
# 6      Rosewood International Hotel - Bar & Restaurant             0
# 8                                       Penthouse Cafe             1
# ...                                                ...           ...
# 51677                                          Bhagini             0
# 51709                       The Farm House Bar n Grill             0
# 51710                                     Topsy Turvey             0
# 51711                                          Bhagini             0
# 51713                         Vinod Bar And Restaurant             0
#
#        BOOK_TABLE      RATE  VOTES      LOCATION     RESTAURANT_TYPE  \
# ...

# %%
# After Removing outliers of Rate attribute
sns.boxplot(x = 'RATE', data = Data)
plt.tight_layout()
plt.savefig('Rating After ouliers.jpg')
plt.show()

# %% [markdown]
# **Explanation:** Now the boxplot is looking like this after removing outlier from the Rate attribute with the help of IQR method.

# %%
numeric = []
category = []
for col in Data:
    if pd.api.types.is_numeric_dtype(Data[col]):
        numeric.append(col)
    else:
        category.append(col)
print("category:", category)
# Out:
# category: ['NAME', 'LOCATION', 'RESTAURANT_TYPE', 'CUISINES', 'REVIEWS', 'SERVICE_TYPE', 'CITY']

# %% [markdown]
# ### **Variance**
# variance () is a built-in function used to calculate the variance from the data.variance() Statistics module provides very powerful tools, which can be used to compute anything related to Statistics.

# %%
#Variance of numeric attributes
Data.var()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ONLINE_ORDER        0.241918
# BOOK_TABLE          0.028185
# RATE                0.115013
# VOTES           10362.665587
# COST            41866.973910
# dtype: float64

# %% [markdown]
# ### **Correlation matrix**
# In machine learning projects, statistical analysis is done on the datasets to identify how the variables are related to each other and how it is dependent on other variables. To find the relationship between the variables, we can plot the correlation matrix.

# %%
corr = Data.corr().round(2)
corr
# Out:
#               ONLINE_ORDER  BOOK_TABLE  RATE  VOTES  COST
# ONLINE_ORDER          1.00        0.04  0.07   0.27  0.07
# BOOK_TABLE            0.04        1.00  0.14   0.22  0.30
# RATE                  0.07        0.14  1.00   0.27  0.04
# VOTES                 0.27        0.22  0.27   1.00  0.33
# COST                  0.07        0.30  0.04   0.33  1.00

# %%
# plotting the correlation matrix with Pearson method
plt.figure(figsize=(10,6))
corr = Data.corr().round(2)
sns.heatmap(corr, annot = True)
plt.title("Correlation Matrix using Pearson Method")
plt.savefig("Correlation Pearson.jpg")
plt.show()

# %%
corr1 = Data.corr(method='spearman').round(2)
corr1
# Out:
#               ONLINE_ORDER  BOOK_TABLE  RATE  VOTES  COST
# ONLINE_ORDER          1.00        0.04  0.07   0.37  0.10
# BOOK_TABLE            0.04        1.00  0.15   0.18  0.23
# RATE                  0.07        0.15  1.00   0.21  0.06
# VOTES                 0.37        0.18  0.21   1.00  0.35
# COST                  0.10        0.23  0.06   0.35  1.00

# %%
#Plotting correlation matrix with Spearman method
corr = Data.corr(method='spearman').round(2)
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True)
plt.title("Correlation Matrix using Spearman Method")
plt.savefig("Correlation Spearman.jpg")
plt.show()

# %% [markdown]
# Explanation: The above chart illustrate the relation between two variables using two different methods of correlation matrix which shows how the change in one variable impact other variable. The value varies between -1 to 1. There is no strong correlation has been observed between these all of the variables.

# %% [markdown]
# ### **We will perform One Hot Encoding operation on online_order, book_table, location, restaurant_type, cuisines, service_type columns**
#  Implementation using Sklearn One-Hot encoding is a technique of representing categorical data in the form of binary vectors. It is a common step in the processing of sequential data before performing classification.

# %%
#Convert categorical variable into dummy variables 
Data['ONLINE_ORDER'] = pd.get_dummies(Data['ONLINE_ORDER'],drop_first=True) #we use One hot encoding method which makes our data more useful & expressive, so it can be rescaled easily.
Data.head(2)
# Out:
#                     NAME  ONLINE_ORDER  BOOK_TABLE  RATE  VOTES      LOCATION  \
# 3  Addhuri Udupi Bhojana             0           0   3.7     88  Banashankari
# 4          Grand Village             0           0   3.8    166  Basavanagudi
#
#   RESTAURANT_TYPE                    CUISINES   COST  \
# 3     Quick Bites  South Indian, North Indian  300.0
# 4   Casual Dining    North Indian, Rajasthani  600.0
#
#                                              REVIEWS SERVICE_TYPE  \
# 3  [('Rated 4.0', "RATED\n  Great food and proper...       Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...       Buffet
#
#            CITY
# 3  Banashankari
# 4  Banashankari

# %%
#Convert categorical variable into dummy variables 
Data['BOOK_TABLE'] = pd.get_dummies(Data['BOOK_TABLE'], drop_first=True)
Data.head(2)
# Out:
#                     NAME  ONLINE_ORDER  BOOK_TABLE  RATE  VOTES      LOCATION  \
# 3  Addhuri Udupi Bhojana             0           0   3.7     88  Banashankari
# 4          Grand Village             0           0   3.8    166  Basavanagudi
#
#   RESTAURANT_TYPE                    CUISINES   COST  \
# 3     Quick Bites  South Indian, North Indian  300.0
# 4   Casual Dining    North Indian, Rajasthani  600.0
#
#                                              REVIEWS SERVICE_TYPE  \
# 3  [('Rated 4.0', "RATED\n  Great food and proper...       Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...       Buffet
#
#            CITY
# 3  Banashankari
# 4  Banashankari

# %%
# Performing One Hot Encoding on restaurant_type
get_dummies_RESTAURANT_TYPE = pd.get_dummies(Data.RESTAURANT_TYPE)
get_dummies_RESTAURANT_TYPE.head(3)
# Out:
#    Bakery  Bakery, Beverage Shop  Bakery, Cafe  Bakery, Dessert Parlor  \
# 3       0                      0             0                       0
# 4       0                      0             0                       0
# 5       0                      0             0                       0
#
#    Bakery, Food Court  Bakery, Kiosk  Bakery, Quick Bites  Bakery, Sweet Shop  \
# 3                   0              0                    0                   0
# 4                   0              0                    0                   0
# 5                   0              0                    0                   0
#
#    Bar  Bar, Cafe  ...  Quick Bites, Food Court  Quick Bites, Kiosk  \
# 3    0          0  ...                        0                   0
# 4    0          0  ...                        0                   0
# 5    0          0  ...                        0                   0
#
#    Quick Bites, Meat Shop  Quick Bites, Mess  Quick Bites, Sweet Shop  \
# ...

# %%
# Performing One Hot Encoding on location
get_dummies_LOCATION = pd.get_dummies(Data.LOCATION)
get_dummies_LOCATION.head(3)
# Out:
#    BTM  Banashankari  Banaswadi  Bannerghatta Road  Basavanagudi  \
# 3    0             1          0                  0             0
# 4    0             0          0                  0             1
# 5    0             0          0                  0             1
#
#    Basaveshwara Nagar  Bellandur  Bommanahalli  Brigade Road  Brookefield  \
# 3                   0          0             0             0            0
# 4                   0          0             0             0            0
# 5                   0          0             0             0            0
#
#    ...  Ulsoor  Uttarahalli  Varthur Main Road, Whitefield  Vasanth Nagar  \
# 3  ...       0            0                              0              0
# 4  ...       0            0                              0              0
# 5  ...       0            0                              0              0
#
#    Vijay Nagar  West Bangalore  Whitefield  Wilson Garden  Yelahanka  \
# ...

# %%
# Performing One Hot Encoding on service_type
get_dummies_SERVICE_TYPE = pd.get_dummies(Data.SERVICE_TYPE)
get_dummies_SERVICE_TYPE.head(3)
# Out:
#    Buffet  Cafes  Delivery  Desserts  Dine-out  Drinks & nightlife  \
# 3       1      0         0         0         0                   0
# 4       1      0         0         0         0                   0
# 5       1      0         0         0         0                   0
#
#    Pubs and bars
# 3              0
# 4              0
# 5              0

# %%
# Concatinating the dataframes
Zom_Data = pd.concat([Data,get_dummies_RESTAURANT_TYPE,get_dummies_SERVICE_TYPE, get_dummies_LOCATION], axis = 1)
Zom_Data.head(3)
# Out:
#                     NAME  ONLINE_ORDER  BOOK_TABLE  RATE  VOTES      LOCATION  \
# 3  Addhuri Udupi Bhojana             0           0   3.7     88  Banashankari
# 4          Grand Village             0           0   3.8    166  Basavanagudi
# 5        Timepass Dinner             1           0   3.8    286  Basavanagudi
#
#   RESTAURANT_TYPE                    CUISINES   COST  \
# 3     Quick Bites  South Indian, North Indian  300.0
# 4   Casual Dining    North Indian, Rajasthani  600.0
# 5   Casual Dining                North Indian  600.0
#
#                                              REVIEWS  ... Ulsoor Uttarahalli  \
# 3  [('Rated 4.0', "RATED\n  Great food and proper...  ...      0           0
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...  ...      0           0
# 5  [('Rated 3.0', 'RATED\n  Food 3/5\nAmbience 3/...  ...      0           0
#
#    Varthur Main Road, Whitefield  Vasanth Nagar  Vijay Nagar  West Bangalore  \
# ...

# %%
Zom_Data = Data.drop(["NAME","RESTAURANT_TYPE","LOCATION", 'CUISINES', 'REVIEWS',"SERVICE_TYPE","CITY"],axis = 1)
Zom_Data.head()
# Out:
#    ONLINE_ORDER  BOOK_TABLE  RATE  VOTES   COST
# 3             0           0   3.7     88  300.0
# 4             0           0   3.8    166  600.0
# 5             1           0   3.8    286  600.0
# 6             0           0   3.6      8  800.0
# 8             1           0   4.0    324  700.0

# %% [markdown]
# ### **Choosing features for our model**

# %%
# Choosing features for our model
Feature= Data[Data.columns[~Data.columns.isin(category)]]
Feature
# Out:
#        ONLINE_ORDER  BOOK_TABLE      RATE  VOTES   COST
# 3                 0           0  3.700000     88  300.0
# 4                 0           0  3.800000    166  600.0
# 5                 1           0  3.800000    286  600.0
# 6                 0           0  3.600000      8  800.0
# 8                 1           0  4.000000    324  700.0
# ...             ...         ...       ...    ...    ...
# 51677             0           0  2.500000     81  800.0
# 51709             0           0  3.700000     34  800.0
# 51710             0           0  3.700526      0  900.0
# 51711             0           0  2.500000     81  800.0
# 51713             0           0  3.700526      0  600.0
#
# [41927 rows x 5 columns]

# %%
Feature.dtypes
# Out:
# ONLINE_ORDER      uint8
# BOOK_TABLE        uint8
# RATE            float64
# VOTES             int64
# COST            float64
# dtype: object

# %% [markdown]
# Which attributes appear to be the most closely associated with the target attribute('Rate')?

# %%
Data.corr()['RATE'].abs().sort_values(ascending=False)
# Out:
# RATE            1.000000
# VOTES           0.272616
# BOOK_TABLE      0.135570
# ONLINE_ORDER    0.071631
# COST            0.036238
# Name: RATE, dtype: float64

# %% [markdown]
# It shows none of the above attributes are closely correlated with the target variable.

# %% [markdown]
# ### **Min-max Scaling**
# Min-Max Scaler It essentially shrinks the range such that the range is now between 0 and 1 (or -1 to 1 if there are negative values).

# %%
# Normalizing our attributes using min max scaler
# y = (y - min_value) / (max_value - min_value)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x = pd.DataFrame(scaler.fit_transform(Zom_Data), columns=Zom_Data.columns)
x
# Out:
#        ONLINE_ORDER  BOOK_TABLE      RATE     VOTES      COST
# 0               0.0         0.0  0.739130  0.181818  0.257426
# 1               0.0         0.0  0.782609  0.342975  0.554455
# 2               1.0         0.0  0.782609  0.590909  0.554455
# 3               0.0         0.0  0.695652  0.016529  0.752475
# 4               1.0         0.0  0.869565  0.669421  0.653465
# ...             ...         ...       ...       ...       ...
# 41922           0.0         0.0  0.217391  0.167355  0.752475
# 41923           0.0         0.0  0.739130  0.070248  0.752475
# 41924           0.0         0.0  0.739359  0.000000  0.851485
# 41925           0.0         0.0  0.217391  0.167355  0.752475
# 41926           0.0         0.0  0.739359  0.000000  0.554455
#
# [41927 rows x 5 columns]

# %% [markdown]
# ### **Separating the independent variables from dependent variables**

# %%
# Splitting the features into independent and dependent variables, Here online order is a dependent variable, we get the values from dummy variables
x = Zom_Data.drop(['ONLINE_ORDER'], axis = 1)
x.head()
# Out:
#    BOOK_TABLE  RATE  VOTES   COST
# 3           0   3.7     88  300.0
# 4           0   3.8    166  600.0
# 5           0   3.8    286  600.0
# 6           0   3.6      8  800.0
# 8           0   4.0    324  700.0

# %%
y = Zom_Data['ONLINE_ORDER']

# %%
y.head(3)
# Out:
# 3    0
# 4    0
# 5    1
# Name: ONLINE_ORDER, dtype: uint8

# %%
Zom_Data
# Out:
#        ONLINE_ORDER  BOOK_TABLE      RATE  VOTES   COST
# 3                 0           0  3.700000     88  300.0
# 4                 0           0  3.800000    166  600.0
# 5                 1           0  3.800000    286  600.0
# 6                 0           0  3.600000      8  800.0
# 8                 1           0  4.000000    324  700.0
# ...             ...         ...       ...    ...    ...
# 51677             0           0  2.500000     81  800.0
# 51709             0           0  3.700000     34  800.0
# 51710             0           0  3.700526      0  900.0
# 51711             0           0  2.500000     81  800.0
# 51713             0           0  3.700526      0  600.0
#
# [41927 rows x 5 columns]

# %% [markdown]
# ### **Splitting train-test**
# The train_test_split function is for splitting a single dataset for two different purposes: training and testing. The testing subset is for building your model. The testing subset is for using the model on unknown data to evaluate the performance of the model.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=3)

# %%
x_train.head(3)
# Out:
#        BOOK_TABLE  RATE  VOTES   COST
# 10455           0   3.9    331  200.0
# 28075           0   4.0     87  200.0
# 50688           0   3.5     20  550.0

# %% [markdown]
# ### **Summarize class distribution**

# %%
print("Before undersampling")             # Before undersampling our dataset is unstable. Here, 0 is for No, and 1 is for yes.
y_train.value_counts()                    # Basically yes and no is for having online order option in restaurant
# Out:
# Before undersampling
# 1    17359
# 0    11989
# Name: ONLINE_ORDER, dtype: int64

# %%
# !pip install imblearn

# %% [markdown]
# ### **Define undersampling strategy**

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
undersample = RandomUnderSampler(sampling_strategy="majority", random_state=4)

# %%
x_train_under, y_train_under= undersample.fit_resample(x_train, y_train)
x_train_under.head(3)
# Out:
#    BOOK_TABLE  RATE  VOTES   COST
# 0           0   3.5     20  550.0
# 1           0   3.3      8  100.0
# 2           0   4.1    324  700.0

# %%
print("after undersampling")             # Here after undersampling our dataset is on the same scale, First we did the undersampling for majority (we did for 0).
y_train_under.value_counts()
# Out:
# after undersampling
# 0    11989
# 1    11989
# Name: ONLINE_ORDER, dtype: int64

# %%
x_train_under.duplicated().sum()
# Out:
# 17194

# %% [markdown]
# ### **Model Implementation and Evaluation**

# %%
# Importing necessary libraries
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn import metrics

# %% [markdown]
# ### **Logistic Regression**

# %% [markdown]
# Linear regression performs the task to predict a dependent variable value (y) based on a given independent variable (x). So, this regression technique finds out a linear relationship between x (input) and y(output).

# %%
# Accuracy for Logistic Regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train_under, y_train_under)
predict_logistic=model.predict(X_test)
cf_matrix_logistic = confusion_matrix(y_test,predict_logistic)
logistic_acc = accuracy_score(y_test,predict_logistic)*100
print("Accuracy of Logistic Regression :", logistic_acc)
# Out:
# Accuracy of Logistic Regression : 60.84744415295334

# %% [markdown]
# ### **K Nearest Neighbors**

# %% [markdown]
# The K in the name of this classifier represents the k nearest neighbors, where k is an integer value specified by the user. Basically, It is a non linear classifier (non-linear classification boundaries to identify the two classes correctly).

# %%
# Accuracy for KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train_under,y_train_under)
pred_k=knn.predict(X_test)
knn_acc = accuracy_score(y_test,pred_k)*100
print("Accuracy of KNN :", knn_acc)
# Out:
# Accuracy of KNN : 72.98672390492091

# %% [markdown]
# ### **Gaussian Navie Bayes**

# %% [markdown]
# A Gaussian Naive Bayes algorithm is a special type of NB algorithm. It's specifically used when the features have continuous values. It's also assumed that all the features are following a gaussian distribution i.e, normal distribution.

# %%
# Accuracy for GaussianNB
from sklearn.naive_bayes import GaussianNB
GNB=GaussianNB()
GNB.fit(x_train_under,y_train_under)
pred_GNB=GNB.predict(X_test)
GNB_acc = accuracy_score(y_test,pred_GNB)*100
print("Accuracy of GNB :", GNB_acc)
# Out:
# Accuracy of GNB : 55.01232212417521

# %% [markdown]
# ### **Random Forest Classifier**

# %% [markdown]
# Random forests is a supervised learning algorithm. It can be used both for classification and regression. Random forests creates decision trees on randomly selected data samples, gets prediction from each tree and selects the best solution by means of voting. It is also non linear classification technique (non-linear classification boundaries to identify the two classes correctly).

# %%
# Accuracy for Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=20)
RFC=model.fit(x_train_under,y_train_under)
pred_RFC=RFC.predict(X_test)
RFC_acc = accuracy_score(y_test,pred_RFC)*100
print("Accuracy of RFC :", RFC_acc)
# Out:
# Accuracy of RFC : 80.34024962238652

# %% [markdown]
# ### **Decision Tree Classifier**

# %% [markdown]
# Decision Trees (DTs) are a non-parametric supervised learning method used for classification and regression. The goal is to create a model that predicts the value of a target variable by learning simple decision rules inferred from the data features.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
model = DecisionTreeClassifier(random_state = 2022)
DTC=model.fit(x_train_under,y_train_under)
pred_DTC = DTC.predict(X_test)
DTC_acc = accuracy_score(y_test,pred_DTC)*100
print("Accuracy of DTC :", round(DTC_acc,2),"%")
# Out:
# Accuracy of DTC : 79.57 %

# %% [markdown]
# ### **Comparing The Accuracies of Models**

# %%
# Comparing Accuracies
labels =["Naive Bayes","Logistic Regression","KNN","Decision Tree","Random Forest"]
x = [GNB_acc,logistic_acc,knn_acc,DTC_acc,RFC_acc]
eval_frame=pd.DataFrame()
eval_frame['Model']=labels
eval_frame['Train_test_split'] = x
eval_frame
# Out:
#                  Model  Train_test_split
# 0          Naive Bayes         55.012322
# 1  Logistic Regression         60.847444
# 2                  KNN         72.986724
# 3        Decision Tree         79.569123
# 4        Random Forest         80.340250

# %% [markdown]
# Explanation: By comparing all the models, the best fit model is is Random Forest Classifier which is having highest accuracy is 80.34%. However, the least accuracy is 55.01% is of Naive Bayes.

# %% [markdown]
# ### **Confusion matrix corresponding to Random Forest Classifier Model**

# %% [markdown]
# A confusion matrix is a table that is used to define the performance of a classification algorithm. Confusion matrices are used to visualize important predictive analytics like recall, specificity, accuracy, and precision. Confusion matrices are useful because they give direct comparisons of values like True Positives, False Positives, True Negatives and False Negatives. In contrast, other machine learning classification metrics like “Accuracy” give less useful information, as Accuracy is simply the difference between correct predictions divided by the total number of predictions.

# %%
# Confusion Matrix corresponding to Random Forest Classifier Model
cf_matrix_RFC = confusion_matrix(y_test, pred_RFC)
cf_matrix_RFC
# Out:
# array([[4624,  580],
#        [1893, 5482]])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, pred_RFC)
plt.figure(figsize=(10,7))
ax=sns.heatmap(cm/np.sum(cm),annot=True,fmt='.2%',cmap="Purples")
ax.set_title('Confusion Matrix corresponding to Random Forest Classifier algorithm')
ax.set_xlabel("Predicted Value")
ax.set_ylabel("Actual Values")

# Ticket labels - list must be in alphabetical order
ax.xaxis.set_ticklabels(['0','1'])
ax.yaxis.set_ticklabels(['0','1'])

# Display the visualization of the Confusion Matrix
plt.savefig("cf_matrix_RFC.jpg",bbox_inches = 'tight')
plt.show()
print("Accuracy of Random Forest :", RFC_acc)
# Out:
# Accuracy of Random Forest : 80.34024962238652

# %% [markdown]
# **Explanation:** The confusion matrix shows the accuracy of the optimal model. It predicted that correspond to 0, only 4% is wrong and 36% is right. Whereas corresponds to 1 is 15% are wrong values and 43% is right. So almost 20% is predicted wrong and 80% is right.

# %%
print(classification_report(y_test, pred_RFC))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.89      0.79      5204
#            1       0.90      0.74      0.82      7375
#
#     accuracy                           0.80     12579
#    macro avg       0.81      0.82      0.80     12579
# weighted avg       0.82      0.80      0.80     12579

# %% [markdown]
# ### **ROC (Receiver Operating Characteristic) Curve with random forest classifier model**
# ROC or Receiver Operating Characteristic curve is used to evaluate logistic regression classification models.It is a very popular method to measure the accuracy of a classification model.

# %%
from sklearn.metrics import RocCurveDisplay, roc_auc_score

# %%
x_train_under, y_train_under= undersample.fit_resample(x_train, y_train)

# %%
clf_rfc = RandomForestClassifier();
clf_rfc.fit(x_train_under, y_train_under); 
y_score = clf_rfc.predict_proba(X_test)[:,1]
print('roc_auc_score for RandomForestClassifier: ', roc_auc_score(y_test, y_score))
# Out:
# roc_auc_score for RandomForestClassifier:  0.8813812712515796

# %%
RFC = RandomForestClassifier(n_estimators=10, random_state=42)
RFC.fit(x_train_under, y_train_under)
ax = plt.gca()
RFC_disp = RocCurveDisplay.from_estimator(RFC, X_test, y_test, ax=ax,  alpha=0.8)
plt.savefig("Roc Curve.jpg",bbox_inches = 'tight')
plt.show()

# %% [markdown]
# **Explanation:** Generally, if the AUC value lies between 0.5 to 1, where 0.5-0.6 auc denotes a bad classifer, 0.7 to 0.8 is considered acceptable, and 1 denotes an excellent classifier and our model gives the auc 0.8 which is very closed to 1, It means our roc curve gives the fair auc score.

# %% [markdown]
# **Optimal feature of the optimal model**

# %%
#important feature to get the high accuracy in optimal model
feature_imp = pd.Series(RFC.feature_importances_,index=x_train.columns).sort_values(ascending=False)
feature_imp
# Out:
# VOTES         0.558727
# RATE          0.223503
# COST          0.208626
# BOOK_TABLE    0.009145
# dtype: float64

# %% [markdown]
# **Conclusion:** My dataset is all about the restaurants in the cities of Bangalore and my dataset is available on the Kaggle. I collected data from CSV file from the Kaggle, from which half of values were missing, and I did not throw up all values, instead of removing NULL values, I tried to fill the values with mean and mode. I have done exploratory data analysis to answer all the research questions. I used one-hot encoded features; I also normalized our data with the help of min-max scaling, I also do train-test-split and do under sampling strategy to stable my dataset and tried different classification models. Random Forest classification is the best fit model of our dataset, so we made confusion matrix corresponding to RFC and made the ROC curve with our optimal model. Moreover, we find out top rated restaurants are present in the BTM city and the minimum rating of all these restaurants are lies under between 3.79 to 3.52. Also, we can say that the average rating of new restaurants in Bangalore would be lies in between the 3.
